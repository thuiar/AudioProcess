# %%
from p2fa import align
WAV_FILE_PATH = '/home/yangkaicheng/Experiments/Paper/音频处理工具/p2fa_py3-master/try/1.wav'
TRANSCRIPTION_FILE_PATH = '/home/yangkaicheng/Experiments/Paper/音频处理工具/p2fa_py3-master/try/1.txt'
phoneme_alignments, word_alignments = align.align(WAV_FILE_PATH,TRANSCRIPTION_FILE_PATH)
print(phoneme_alignments,word_alignments)
# Out:
# [['AE1', 0.0125, 0.042499999999999996], ['N', 0.042499999999999996, 0.0825], ['D', 0.0825, 0.1125], ['AY1', 0.1125, 0.1925], ['W', 0.1925, 0.2225], ['UH1', 0.2225, 0.2525], ['D', 0.2525, 0.28250000000000003], ['W', 0.28250000000000003, 0.3425], ['AA1', 0.3425, 0.4825], ['N', 0.4825, 0.5125], ['T', 0.5125, 0.5425], ['DH', 0.5425, 0.7024999999999999], ['IY0', 0.7024999999999999, 0.8225], ['sp', 0.8225, 0.9225], ['S', 0.9225, 1.0025], ['IY1', 1.0025, 1.0725], ['K', 1.0725, 1.1025], ['W', 1.1025, 1.1325], ['AH0', 1.1325, 1.1724999999999999], ['N', 1.1724999999999999, 1.2025], ['S', 1.2025, 1.2925], ['AH0', 1.2925, 1.3225], ['Z', 1.3225, 1.3924999999999998], ['T', 1.3924999999999998, 1.4425], ['AH0', 1.4425, 1.4825], ['B', 1.4825, 1.5225], ['IY1', 1.5225, 1.6325], ['IY1', 1.6325, 1.7525], ['V', 1.7525, 1.7825], ['AH0', 1.7825, 1.8225], ['N', 1.8225, 1.8525], ['L', 1.8525, 1.8825], ['AO1', 1.8825, 2.0725000000000002], ['NG', 2.0725000000000002, 2.1025], ['G', 2.1025, 2.1525000000000003], [
# ...
